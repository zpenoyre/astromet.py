# %%
# optional but useful for debugging - reimports modules after editing and saving .py files
# %load_ext autoreload
# %autoreload 2

# %%
import numpy as np
import astropy
from astropy import units as u
import astromet
#import dev.astromet.astromet as astromet
import matplotlib.pyplot as plt
import matplotlib as mpl
from tqdm import tqdm
import scanninglaw.times
from scanninglaw.source import Source

# %%
plt.style.use('ggplot')
# %config InlineBackend.figure_format = 'retina'
mpl.rcParams['lines.linewidth'] = 2.5
mpl.rcParams['axes.facecolor']='white'
mpl.rcParams['axes.edgecolor']='k'
mpl.rcParams['axes.linewidth']=2
mpl.rcParams['font.family'] = 'serif'
mpl.rcParams['text.color'] = 'k'
#mpl.rcParams['xtick.major.width'] = 2
#mpl.rcParams['ytick.major.width'] = 2
mpl.rcParams['xtick.color']='k'
mpl.rcParams['ytick.color']='k'
mpl.rcParams['axes.labelcolor']='k'

mpl.rcParams['font.size']=12
mpl.rcParams['xtick.direction']='in'
mpl.rcParams['ytick.direction']='in'
mpl.rcParams['xtick.major.size'] = 5.5
mpl.rcParams['ytick.major.size'] = 5.5
mpl.rcParams['xtick.minor.size'] = 3.5
mpl.rcParams['ytick.minor.size'] = 3.5

# %%
# slooow step - see scanning_law package for details
dr3_sl=scanninglaw.times.dr2_sl(version='dr3_nominal')
# Out:
# Loading auxilliary data ...
# t = 50.789 s
#   auxilliary:  30.673 s
#           sf:   5.682 s
# interpolator:  14.434 s

# %%
dr3Period=34/12 # in years
mas=astromet.mas # conversion from degrees to milli-arcseconds

# %%
nTest=16
dataNames=('RA','Dec','pmRA','pmDec','pllx',
           'M_tot','q','l','a','e','P','tPeri',
           'vTheta','vPhi','vOmega',
           'predict_dTheta','simple_dTheta',
           'N_obs','sigma_al','sigma_ac',
           'fit_ra','fit_dec','fit_pmrac','fit_pmdec','fit_pllx',
           'sigma_rac','sigma_dec','sigma_pmrac','sigma_pmdec','sigma_pllx',
           'N_vis','frac_good','AEN','UWE'
          )
allData=astropy.table.Table(names=dataNames)

alError=1e-10#1
#acError=0.3  -- currently ignoring across scan measurements (~negligible change)

# we'll generate nTest sets of parameters, and test each with a 0, 2 ,5 and 10 mSun BH
for i in tqdm(range(nTest)):
    allData.add_row()
    thisRow=allData[i]
    
    params=astromet.params()
    params.ra=360*np.random.rand()
    params.dec=np.arcsin(-1+2*np.random.rand())*180/np.pi
    
    c=Source(params.ra,params.dec,unit='deg')
    sl=dr3_sl(c, return_times=True, return_angles=True)
    ts=2010+np.squeeze(np.hstack(sl['times']))/365.25
    sort=np.argsort(ts)
    ts=ts[sort]
    
    phis=np.squeeze(np.hstack(sl['angles']))[sort]
    
    params.pllx=10*np.power(np.random.rand(),-1/3) # all within 100 pc
    params.pmrac=params.pllx*(1)*np.random.randn()
    params.pmdec=params.pllx*(1)*np.random.randn()
    params.period=10**(-1.5+3*np.random.rand()) # periods between 0.03 and 30 years
    params.l=np.random.rand() # uniform light ratio
    params.q=4*np.random.rand()**2 # mass ratios between 0 and 4 (half less than 1)
    params.a=10*np.random.rand()**2
    params.e=np.random.rand()
    params.vtheta=np.arccos(-1+2*np.random.rand())
    params.vphi=2*np.pi*np.random.rand()
    params.vomega=2*np.pi*np.random.rand()
    orbitalPhase=np.random.rand() # fraction of an orbit completed at t=0
    params.tperi=params.period*orbitalPhase
    
    thisRow['RA']=1.*params.ra
    thisRow['Dec']=1.*params.dec
    thisRow['pmRA']=params.pmrac
    thisRow['pmDec']=params.pmdec
    thisRow['pllx']=params.pllx
    thisRow['M_tot']=4*(np.pi**2)*astromet.Galt/((params.period**2)*(params.a**3))
    thisRow['q']=params.q
    thisRow['l']=params.l
    thisRow['a']=0#params.a
    thisRow['e']=params.e
    thisRow['P']=params.period
    thisRow['tPeri']=1.*params.tperi
    thisRow['vTheta']=params.vtheta
    thisRow['vPhi']=params.vphi
    thisRow['vOmega']=params.vomega
    thisRow['sigma_al']=alError
    #thisRow['sigma_ac']=acError
    
    trueRacs,trueDecs=astromet.track(ts,params)
    '''
    alErrs=alError*np.random.randn(ts.size)
    #acErrs=acError*np.random.randn(ts.size)
    
    radphis=np.deg2rad(phis)
    
    racErrs=alErrs*np.sin(radphis)#+acErrs*np.cos(np.deg2rad(phis))
    obsRacs=trueRacs+racErrs
    
    decErrs=alErrs*np.cos(radphis)#+acErrs*np.sin(np.deg2rad(phis))
    obsDecs=trueDecs+decErrs
    
    xs=obsRacs*np.sin(radphis) + obsDecs*np.cos(radphis)'''
    t_obs,x_obs,phi_obs,rac_obs,dec_obs=astromet.gaia_mock(ts,phis,trueRacs,trueDecs,err=alError)
    
    #print('t size: ',ts.size)
    #print('xs size: ',xs.size)
    #print('phis size: ',phis.size)
    
    results=astromet.gaia_fit(t_obs,x_obs,phi_obs,alError,params.ra,params.dec)
    #results=astromet.simple_fit(ts,obsRacs,obsDecs,alError,params.ra,params.dec)
    print('ra, dec, pllx, pmrac, pmdec ',params.ra,params.dec,params.parallax,params.pmrac,params.pmdec)
    print(results)
    
    thisRow['simple_dTheta']=astromet.dtheta_simple(params)
    thisRow['predict_dTheta']=astromet.dtheta_full(params,np.min(ts),np.max(ts))  
    
    thisRow['fit_ra']=results['ra']
    thisRow['fit_dec']=results['dec']
    thisRow['fit_pmrac']=results['pmra']
    thisRow['fit_pmdec']=results['pmdec']
    thisRow['fit_pllx']=results['parallax']

    thisRow['sigma_rac']=results['ra_error']
    thisRow['sigma_dec']=results['dec_error']
    thisRow['sigma_pmrac']=results['pmra_error']
    thisRow['sigma_pmdec']=results['pmdec_error']
    thisRow['sigma_pllx']=results['parallax_error']

    thisRow['UWE']=results['UWE']

    thisRow['N_obs']=results['astrometric_n_obs_al']
    #thisRow['frac_good']=results['astrometric_n_good_obs_al']/results['astrometric_n_obs_al']
    thisRow['N_vis']=results['visibility_periods_used']
    #thisRow['AEN']=results['astrometric_excess_noise']
    
    # optionally plot tracks
    plotts=np.linspace(ts[0],ts[-1],1000)
    cs=mpl.cm.twilight_shifted(np.interp(plotts,[plotts[0],plotts[-1]],[0,1]))
    
    plotRacs,plotDecs=astromet.track(plotts,params)
    
    ax=plt.gca()
    fitparams=astromet.params()
    for i in range(16):
        fitparams.ra=results['ra']
        +np.random.randn()*results['ra_error']#/(np.cos(np.deg2rad(results['dec']))*mas)
        fitparams.dec=results['dec']+np.random.randn()*results['dec_error']#/mas
        fitparams.pmrac=results['pmra']+np.random.randn()*results['pmra_error']
        fitparams.pmdec=results['pmdec']+np.random.randn()*results['pmdec_error']
        fitparams.pllx=results['parallax']+np.random.randn()*results['parallax_error']
        
        fitRacs,fitDecs=astromet.track(plotts,fitparams)
        ax.plot(fitRacs,fitDecs,c='k',alpha=0.2,lw=0.5)
    ax.scatter(plotRacs,plotDecs,c=cs,s=10,alpha=0.8)
    ax.set_xlabel(r'$\delta \ RA \cos(Dec) \ \ [mas]$')
    ax.set_ylabel(r'$\delta \ Dec \ \ [mas]$')

    plt.show()
    #print(thisRow)
# Out:
#   0%|          | 0/16 [00:00<?, ?it/s]
# ra, dec, pllx, pmrac, pmdec  253.2753406736487 30.46253943136717 1 25.14300772086041 0.4387926013005745
# {'astrometric_matched_transits': 57, 'visibility_periods_used': 29, 'astrometric_n_obs_al': 513, 'astrometric_params_solved': 31, 'ra': 253.2753398454676, 'ra_error': 0.04671585847303677, 'dec': 30.46253986096867, 'dec_error': 0.04746933752538137, 'ra_dec_corr': 0.15328073739005485, 'parallax': 1.185729725552329, 'parallax_error': 0.057612165952352946, 'ra_parallax_corr': 0.05744999958151838, 'dec_parallax_corr': 0.016467071655459437, 'pmra': 25.145592157807794, 'pmra_error': 0.061121700496669776, 'ra_pmra_corr': 0.2653605916054913, 'dec_pmra_corr': -0.0032989656700199597, 'parallax_pmra_corr': 0.0781110874351472, 'pmdec': 0.5409805545710151, 'pmdec_error': 0.06042798036568159, 'ra_pmdec_corr': 0.01424190136156557, 'dec_pmdec_corr': -0.13768490993810772, 'parallax_pmdec_corr': 0.012495187792218164, 'pmra_pmdec_corr': 0.19748355067838663, 'astrometric_excess_noise': 0.5141579551104742, 'astrometric_chi2_al': 2.169031821843791e+22, 'astrometric_n_good_obs_al': 504, 'UWE': 6592994128.621372}
# /Users/zephyr/Google Drive/astro/pythonModules/dev/astromet/astromet/track.py:400: RuntimeWarning: invalid value encountered in sqrt
#   return np.sqrt(epsxsq+epsysq-(epsx**2)-(epsy**2))
# /Users/zephyr/Google Drive/astro/pythonModules/dev/astromet/astromet/track.py:435: RuntimeWarning: invalid value encountered in sqrt
#   return np.sqrt(epsxsq+epsysq-(epsx**2)-(epsy**2))
#   6%|▋         | 1/16 [00:02<00:37,  2.50s/it]
# ra, dec, pllx, pmrac, pmdec  256.3383974325612 31.281350795141865 1 -4.327599461289507 8.227103347764073
# {'astrometric_matched_transits': 52, 'visibility_periods_used': 28, 'astrometric_n_obs_al': 468, 'astrometric_params_solved': 31, 'ra': 256.33839752481015, 'ra_error': 0.03489604727274052, 'dec': 31.28135082900512, 'dec_error': 0.03857551796996605, 'ra_dec_corr': 0.08959309688573838, 'parallax': 1.048456134576393, 'parallax_error': 0.04467539588884355, 'ra_parallax_corr': 0.15832019739658654, 'dec_parallax_corr': 0.00216329406668613, 'pmra': -4.375548301428829, 'pmra_error': 0.04584651448356167, 'ra_pmra_corr': 0.07321969899168461, 'dec_pmra_corr': -0.10356762687692168, 'parallax_pmra_corr': 0.1481646180754088, 'pmdec': 8.478472023361482, 'pmdec_error': 0.05103111477971125, 'ra_pmdec_corr': -0.06952607087700678, 'dec_pmdec_corr': -0.16947437329996806, 'parallax_pmdec_corr': 0.024412045455675244, 'pmra_pmdec_corr': 0.23158781044229337, 'astrometric_excess_noise': 0.2971260124048507, 'astrometric_chi2_al': 4.4634472671146127e+21, 'astrometric_n_good_obs_al': 468, 'UWE': 3104879204.571019}
# /Users/zephyr/Google Drive/astro/pythonModules/dev/astromet/astromet/track.py:435: RuntimeWarning: invalid value encountered in sqrt
#   return np.sqrt(epsxsq+epsysq-(epsx**2)-(epsy**2))
#  88%|████████▊ | 14/16 [00:26<00:03,  1.86s/it]/Users/zephyr/Google Drive/astro/pythonModules/dev/astromet/astromet/track.py:435: RuntimeWarning: invalid value encountered in sqrt
#   return np.sqrt(epsxsq+epsysq-(epsx**2)-(epsy**2))
# ra, dec, pllx, pmrac, pmdec  128.4817363730536 6.337543458670916 1 -23.506751606380842 -2.0019915218462114
# {'astrometric_matched_transits': 29, 'visibility_periods_used': 16, 'astrometric_n_obs_al': 261, 'astrometric_params_solved': 31, 'ra': 128.48173637307977, 'ra_error': 0.0015942276684541578, 'dec': 6.337543458570233, 'dec_error': 0.0011038050069070741, 'ra_dec_corr': -0.10987611432236208, 'parallax': 0.9998567071868528, 'parallax_error': 0.0017927725927529515, 'ra_parallax_corr': 0.06274064652498973, 'dec_parallax_corr': 0.07766180760211974, 'pmra': -23.50659731268312, 'pmra_error': 0.001971867806779076, 'ra_pmra_corr': -0.05022782427363498, 'dec_pmra_corr': 0.07697717193597813, 'parallax_pmra_corr': -0.20419452214256226, 'pmdec': -2.0019892475786287, 'pmdec_error': 0.0014437770511915855, 'ra_pmdec_corr': 0.11260028184725712, 'dec_pmdec_corr': -0.08578480243709638, 'parallax_pmdec_corr': 0.09236901446351704, 'pmra_pmdec_corr': -0.032712128276013205, 'astrometric_excess_noise': 0.0002081198057342541, 'astrometric_chi2_al': 1108834650595165.6, 'astrometric_n_good_obs_al': 261, 'UWE': 2081198.057342781}
#  94%|█████████▍| 15/16 [00:27<00:01,  1.74s/it]
# ra, dec, pllx, pmrac, pmdec  196.67491350546308 12.098006421489034 1 -20.716767159889116 -20.45435239397692
# {'astrometric_matched_transits': 46, 'visibility_periods_used': 18, 'astrometric_n_obs_al': 414, 'astrometric_params_solved': 31, 'ra': 196.67491333031035, 'ra_error': 0.09701089949430601, 'dec': 12.098006786126806, 'dec_error': 0.0701381958244743, 'ra_dec_corr': -0.4593894942299316, 'parallax': 2.3923632245347033, 'parallax_error': 0.12789186980069836, 'ra_parallax_corr': 0.10810583069790604, 'dec_parallax_corr': 0.06539122109552203, 'pmra': -20.43885013825415, 'pmra_error': 0.14935611218489553, 'ra_pmra_corr': 0.2123145317095687, 'dec_pmra_corr': -0.10487834298633017, 'parallax_pmra_corr': -0.08712291248435386, 'pmdec': -18.41225668320514, 'pmdec_error': 0.17608553246133055, 'ra_pmdec_corr': 0.027025081936976766, 'dec_pmdec_corr': 0.26334867417560637, 'parallax_pmdec_corr': 0.29271908040670036, 'pmra_pmdec_corr': -0.4685924409685, 'astrometric_excess_noise': 0.8909880654824783, 'astrometric_chi2_al': 6.037539773891143e+22, 'astrometric_n_good_obs_al': 405, 'UWE': 12285702843.031755}
# 100%|██████████| 16/16 [00:28<00:00,  1.81s/it]

# %%
qPl=plt.gca()
qPl.scatter(allData['P'],allData['UWE'])
qPl.set_xscale('log')
qPl.set_yscale('log')
plt.show()

# %%
# can work on plotting whilst messing with allData
fname='data/simulatedBinariesMock.ecsv'
exists=0
if exists==0:
    plotData=allData[:][:]
    print(plotData)
    astropy.io.ascii.write(plotData,fname,format='ecsv',overwrite=True)
if exists==1:
    plotData=astropy.io.ascii.read(fname)
